# %%
import os
import keras
import metrics
import numpy as np
import pandas as pd
import keras.backend as K
from keras.models import load_model
from keras.optimizers import SGD
from time import time
import matplotlib.pyplot as plt
from keras.initializers import VarianceScaling,RandomNormal
from keras.engine.topology import Layer, InputSpec
import seaborn as sns
import pickle
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import animation, rc
from IPython.display import HTML

folder_name = 'results_with_uniform_glorot' # for saving the results

# %%
from DEC import DEC , plot_animated_history

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train_r = x_train.reshape(60000,28*28)
x_test_r = x_test.reshape(10000,28*28)
x_train_r.shape
# Out:
# (60000, 784)

# %%
x_train_r = pickle.load(open( "results_with_uniform_glorot/x_train_r.p", "rb" ))

# %%
(1.3*5 +1.1*6 +1*6+3.3*6)/(5+6+6+6)
# Out:
# 1.691304347826087

# %%
#init = VarianceScaling(scale=1. / .02, mode='fan_in', distribution='uniform')  
#init = RandomNormal(mean=0.0, stddev=0.05, seed=None)
init = 'glorot_uniform'
dec = DEC(dims=[784, 500, 300, 200, 50, 3], n_clusters=10, init=init)
Encoded = dec.encoder.predict(x_train_r)
fig = pyplot.figure(figsize=(10,10))
ax = Axes3D(fig)
ax.scatter(Encoded[:,0], Encoded[:,1], Encoded[:,2], s=0.05, c = 'purple', marker='o')

# %%
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

dec.pretrain(x=x_train_r,
               y=None,
               #validation_data=(x_test_r, x_test_r),
               validation_split=0.1,
               optimizer='adam',
               epochs=500,
               batch_size=1024,
               save_dir=folder_name)
# Out:
# ...Pretraining...
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/500
# 54000/54000 [==============================] - 25s 469us/step - loss: 4245.5326 - val_loss: 3441.5138
# Epoch 2/500
#  1024/54000 [..............................] - ETA: 6:27 - loss: 3446.3655
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.243014). Check your callbacks.
#   % delta_t_median)
# 54000/54000 [==============================] - 25s 464us/step - loss: 3197.0378 - val_loss: 2971.5256
# Epoch 3/500
# 54000/54000 [==============================] - 26s 476us/step - loss: 2853.1365 - val_loss: 2719.6279
# Epoch 4/500
# 54000/54000 [==============================] - 31s 574us/step - loss: 2653.8980 - val_loss: 2550.3121
# Epoch 5/500
# 54000/54000 [==============================] - 29s 535us/step - loss: 2513.9753 - val_loss: 2447.9346
# Epoch 6/500
# 54000/54000 [==============================] - 31s 566us/step - loss: 2419.6401 - val_loss: 2368.4186
# Epoch 7/500
#  1024/54000 [..............................] - ETA: 7:39 - loss: 2418.7271
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.356020). Check your callbacks.
#   % delta_t_median)
# 54000/54000 [==============================] - 33s 606us/step - loss: 2353.3402 - val_loss: 2319.0888
# Epoch 8/500
# 54000/54000 [==============================] - 27s 505us/step - loss: 2306.3701 - val_loss: 2283.9739
# Epoch 9/500
# 54000/54000 [==============================] - 30s 549us/step - loss: 2268.9483 - val_loss: 2246.0122
# Epoch 10/500
# 54000/54000 [==============================] - 35s 657us/step - loss: 2236.9186 - val_loss: 2221.3963
# Epoch 11/500
#  1024/54000 [..............................] - ETA: 7:40 - loss: 2220.3142
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.386022). Check your callbacks.
#   % delta_t_median)
# 54000/54000 [==============================] - 27s 494us/step - loss: 2212.7358 - val_loss: 2204.7075
# Epoch 12/500
# 54000/54000 [==============================] - 35s 654us/step - loss: 2193.1421 - val_loss: 2174.3118
# Epoch 13/500
#  4096/54000 [=>............................] - ETA: 2:13 - loss: 2174.2521
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.252514). Check your callbacks.
#   % delta_t_median)
#  7168/54000 [==>...........................] - ETA: 1:19 - loss: 2180.5702
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.225013). Check your callbacks.
#   % delta_t_median)
# 54000/54000 [==============================] - 28s 518us/step - loss: 2171.0577 - val_loss: 2158.4892
# Epoch 14/500
# 54000/54000 [==============================] - 35s 649us/step - loss: 2162.8380 - val_loss: 2150.9165
# Epoch 15/500
# 54000/54000 [==============================] - 27s 497us/step - loss: 2147.7599 - val_loss: 2134.5880
# Epoch 16/500
# 54000/54000 [==============================] - 29s 535us/step - loss: 2131.5609 - val_loss: 2116.1906
# Epoch 17/500
# 54000/54000 [==============================] - 35s 644us/step - loss: 2120.3975 - val_loss: 2112.7415
# Epoch 18/500
# 54000/54000 [==============================] - 28s 513us/step - loss: 2106.4548 - val_loss: 2111.6766
# Epoch 19/500
# 54000/54000 [==============================] - 33s 614us/step - loss: 2095.5818 - val_loss: 2099.8866
# Epoch 20/500
# 54000/54000 [==============================] - 27s 509us/step - loss: 2084.9929 - val_loss: 2088.0619
# Epoch 21/500
# 54000/54000 [==============================] - 36s 659us/step - loss: 2081.9822 - val_loss: 2083.2376
# Epoch 22/500
# 54000/54000 [==============================] - 28s 524us/step - loss: 2074.4137 - val_loss: 2079.1979
# Epoch 23/500
# 54000/54000 [==============================] - 33s 617us/step - loss: 2065.2085 - val_loss: 2066.2454
# Epoch 24/500
# 54000/54000 [==============================] - 39s 716us/step - loss: 2057.2840 - val_loss: 2063.2862
# Epoch 25/500
#  1024/54000 [..............................] - ETA: 8:03 - loss: 2045.7859
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.910110). Check your callbacks.
#   % delta_t_median)
#  2048/54000 [>.............................] - ETA: 4:52 - loss: 2051.1063
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.416138). Check your callbacks.
#   % delta_t_median)
#  4096/54000 [=>............................] - ETA: 3:20 - loss: 2038.2189
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.753600). Check your callbacks.
#   % delta_t_median)
#  5120/54000 [=>............................] - ETA: 2:54 - loss: 2033.5157
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.741100). Check your callbacks.
#   % delta_t_median)
#  6144/54000 [==>...........................] - ETA: 2:37 - loss: 2032.1426
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.825605). Check your callbacks.
#   % delta_t_median)
#  8192/54000 [===>..........................] - ETA: 2:40 - loss: 2032.5766
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.160624). Check your callbacks.
#   % delta_t_median)
#  9216/54000 [====>.........................] - ETA: 2:32 - loss: 2034.3757
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.927110). Check your callbacks.
#   % delta_t_median)
# 10240/54000 [====>.........................] - ETA: 2:23 - loss: 2040.5085
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.918610). Check your callbacks.
#   % delta_t_median)
# 11264/54000 [=====>........................] - ETA: 2:11 - loss: 2037.1477
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.068118). Check your callbacks.
#   % delta_t_median)
# 12288/54000 [=====>........................] - ETA: 2:06 - loss: 2042.7607
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.834105). Check your callbacks.
#   % delta_t_median)
# 13312/54000 [======>.......................] - ETA: 1:59 - loss: 2044.4227
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.990114). Check your callbacks.
#   % delta_t_median)
# 15360/54000 [=======>......................] - ETA: 1:49 - loss: 2044.1571
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.131122). Check your callbacks.
#   % delta_t_median)
# 18432/54000 [=========>....................] - ETA: 1:45 - loss: 2046.3999
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.017615). Check your callbacks.
#   % delta_t_median)
# 21504/54000 [==========>...................] - ETA: 1:29 - loss: 2045.7881
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.871607). Check your callbacks.
#   % delta_t_median)
# 23552/54000 [============>.................] - ETA: 1:19 - loss: 2048.4944
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.742600). Check your callbacks.
#   % delta_t_median)
# 24576/54000 [============>.................] - ETA: 1:14 - loss: 2047.2439
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.296574). Check your callbacks.
#   % delta_t_median)
# 25600/54000 [=============>................] - ETA: 1:09 - loss: 2045.6015
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.175067). Check your callbacks.
#   % delta_t_median)
# 30720/54000 [================>.............] - ETA: 59s - loss: 2044.3455
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.414581). Check your callbacks.
#   % delta_t_median)
# 31744/54000 [================>.............] - ETA: 55s - loss: 2044.2684
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.710098). Check your callbacks.
#   % delta_t_median)
# 32768/54000 [=================>............] - ETA: 52s - loss: 2044.7090
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.005615). Check your callbacks.
#   % delta_t_median)
# 33792/54000 [=================>............] - ETA: 50s - loss: 2045.8589
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.064118). Check your callbacks.
#   % delta_t_median)
# 34816/54000 [==================>...........] - ETA: 47s - loss: 2047.2602
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.210127). Check your callbacks.
#   % delta_t_median)
# 35840/54000 [==================>...........] - ETA: 46s - loss: 2046.6437
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.610649). Check your callbacks.
#   % delta_t_median)
# 36864/54000 [===================>..........] - ETA: 44s - loss: 2046.4442
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.958669). Check your callbacks.
#   % delta_t_median)
# 37888/54000 [====================>.........] - ETA: 42s - loss: 2046.1044
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.636151). Check your callbacks.
#   % delta_t_median)
# 38912/54000 [====================>.........] - ETA: 39s - loss: 2046.6553
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.304632). Check your callbacks.
#   % delta_t_median)
# 39936/54000 [=====================>........] - ETA: 36s - loss: 2047.6326
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.150123). Check your callbacks.
#   % delta_t_median)
# 41984/54000 [======================>.......] - ETA: 31s - loss: 2049.1708
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.546646). Check your callbacks.
#   % delta_t_median)
# 43008/54000 [======================>.......] - ETA: 28s - loss: 2048.8176
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.917167). Check your callbacks.
#   % delta_t_median)
# 44032/54000 [=======================>......] - ETA: 26s - loss: 2048.7052
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (3.150680). Check your callbacks.
#   % delta_t_median)
# 45056/54000 [========================>.....] - ETA: 23s - loss: 2048.1058
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (3.084177). Check your callbacks.
#   % delta_t_median)
# 46080/54000 [========================>.....] - ETA: 21s - loss: 2048.3328
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.879165). Check your callbacks.
#   % delta_t_median)
# 49152/54000 [==========================>...] - ETA: 12s - loss: 2047.5777
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.703655). Check your callbacks.
#   % delta_t_median)
# 52224/54000 [============================>.] - ETA: 4s - loss: 2049.4711
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (3.096177). Check your callbacks.
#   % delta_t_median)
# 53248/54000 [============================>.] - ETA: 2s - loss: 2049.9940
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (3.039174). Check your callbacks.
#   % delta_t_median)
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.863664). Check your callbacks.
#   % delta_t_median)
# 54000/54000 [==============================] - 151s 3ms/step - loss: 2049.9306 - val_loss: 2060.3418
# Epoch 26/500
#  1024/54000 [..............................] - ETA: 6:14 - loss: 2088.1736
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.181124). Check your callbacks.
#   % delta_t_median)
#  2048/54000 [>.............................] - ETA: 4:04 - loss: 2050.6401
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.612649). Check your callbacks.
#   % delta_t_median)
#  3072/54000 [>.............................] - ETA: 3:34 - loss: 2051.5720
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.197126). Check your callbacks.
#   % delta_t_median)
#  4096/54000 [=>............................] - ETA: 3:07 - loss: 2051.7239
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.620650). Check your callbacks.
#   % delta_t_median)
#  5120/54000 [=>............................] - ETA: 3:01 - loss: 2060.3186
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.582148). Check your callbacks.
#   % delta_t_median)
#  6144/54000 [==>...........................] - ETA: 2:50 - loss: 2060.4279
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.559646). Check your callbacks.
#   % delta_t_median)
#  8192/54000 [===>..........................] - ETA: 2:40 - loss: 2053.9877
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.664153). Check your callbacks.
#   % delta_t_median)
# 12288/54000 [=====>........................] - ETA: 1:54 - loss: 2047.5019
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (2.367135). Check your callbacks.
#   % delta_t_median)
# 13312/54000 [======>.......................] - ETA: 1:44 - loss: 2045.7549
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (1.609592). Check your callbacks.
#   % delta_t_median)
# 14336/54000 [======>.......................] - ETA: 1:35 - loss: 2046.1116
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.566532). Check your callbacks.
#   % delta_t_median)
# 15360/54000 [=======>......................] - ETA: 1:28 - loss: 2046.3151
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.430025). Check your callbacks.
#   % delta_t_median)
# 16384/54000 [========>.....................] - ETA: 1:21 - loss: 2047.6674
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.332019). Check your callbacks.
#   % delta_t_median)
# 17408/54000 [========>.....................] - ETA: 1:16 - loss: 2045.9851
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.250514). Check your callbacks.
#   % delta_t_median)
# 18432/54000 [=========>....................] - ETA: 1:10 - loss: 2046.5060
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.238014). Check your callbacks.
#   % delta_t_median)
# 20480/54000 [==========>...................] - ETA: 1:01 - loss: 2047.8472
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.228013). Check your callbacks.
#   % delta_t_median)
# 22528/54000 [===========>..................] - ETA: 53s - loss: 2049.1001
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.221013). Check your callbacks.
#   % delta_t_median)
# 54000/54000 [==============================] - 51s 936us/step - loss: 2041.4415 - val_loss: 2051.9466
# Epoch 27/500
# 54000/54000 [==============================] - 26s 477us/step - loss: 2035.5228 - val_loss: 2053.6645
# Epoch 28/500
# 54000/54000 [==============================] - 24s 451us/step - loss: 2037.2110 - val_loss: 2043.7584
# Epoch 29/500
# 54000/54000 [==============================] - 29s 541us/step - loss: 2025.2512 - val_loss: 2036.5872
# Epoch 30/500
# 54000/54000 [==============================] - 24s 441us/step - loss: 2017.2274 - val_loss: 2034.3107
# Epoch 31/500
# 54000/54000 [==============================] - 34s 622us/step - loss: 2012.5087 - val_loss: 2036.1223
# Epoch 32/500
# 54000/54000 [==============================] - 26s 480us/step - loss: 2011.6978 - val_loss: 2034.3368
# Epoch 33/500
# 54000/54000 [==============================] - 29s 530us/step - loss: 2006.0048 - val_loss: 2026.1434
# Epoch 34/500
# 54000/54000 [==============================] - 34s 625us/step - loss: 2002.6232 - val_loss: 2017.4561
# Epoch 35/500
# 54000/54000 [==============================] - 26s 472us/step - loss: 1997.3503 - val_loss: 2012.7695
# Epoch 36/500
# 54000/54000 [==============================] - 29s 530us/step - loss: 1994.7633 - val_loss: 2019.1444
# Epoch 37/500
# 54000/54000 [==============================] - 28s 522us/step - loss: 1611.5467 - val_loss: 1777.3869
# Epoch 490/500
# 54000/54000 [==============================] - 31s 568us/step - loss: 1607.6487 - val_loss: 1782.6317
# Epoch 491/500
# 54000/54000 [==============================] - 37s 686us/step - loss: 1610.0610 - val_loss: 1775.9578
# Epoch 492/500
# 54000/54000 [==============================] - 26s 473us/step - loss: 1608.6713 - val_loss: 1785.2403
# Epoch 493/500
# 54000/54000 [==============================] - 37s 681us/step - loss: 1613.2859 - val_loss: 1772.1616
# Epoch 494/500
# 54000/54000 [==============================] - 26s 481us/step - loss: 1603.8265 - val_loss: 1773.4277
# Epoch 495/500
# 54000/54000 [==============================] - 36s 672us/step - loss: 1595.6959 - val_loss: 1766.8471
# Epoch 496/500
# 54000/54000 [==============================] - 26s 489us/step - loss: 1596.1056 - val_loss: 1773.9289
# Epoch 497/500
# 54000/54000 [==============================] - 35s 657us/step - loss: 1596.7553 - val_loss: 1772.1542
# Epoch 498/500
# 54000/54000 [==============================] - 27s 505us/step - loss: 1602.9637 - val_loss: 1776.6388
# Epoch 499/500
# 54000/54000 [==============================] - 35s 645us/step - loss: 1595.2642 - val_loss: 1780.9111
# Epoch 500/500
# 54000/54000 [==============================] - 28s 515us/step - loss: 1591.2655 - val_loss: 1768.1256
# Pretraining time:  17215.65721511841
# Pretrained weights are saved to results_with_uniform_glorot/ae_weights.h5

# %%
plot_animated_history(dec.encoders_predictions_history[:],  threeD=True,   saving_name=folder_name+'/pretraining.mp4')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-539d8a04e54e> in <module>
# ----> 1 plot_animated_history(dec.encoders_predictions_history[:],  threeD=True,   saving_name=folder_name+'/pretraining.mp4')
#
# ~\Desktop\exp ae\DEC.py in plot_animated_history(enc_pred, saving_name, threeD)
#     275         Writer = animation.writers['ffmpeg']
#     276         writer = Writer(fps=10, metadata=dict(artist='Me'), bitrate=6800)
# --> 277         anim.save(saving_name, writer=writer)
#     278     return HTML(anim.to_html5_video())
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1171                     for anim, d in zip(all_anim, data):
#    1172                         # TODO: See if turning off blit is really necessary
# -> 1173                         anim._draw_next_frame(d, blit=False)
#    1174                     writer.grab_frame(**savefig_kwargs)
#    1175
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\animation.py in _draw_next_frame(self, framedata, blit)
#    1209         self._pre_draw(framedata, blit)
#    1210         self._draw_frame(framedata)
# -> 1211         self._post_draw(framedata, blit)
#    1212
#    1213     def _init_draw(self):
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\animation.py in _post_draw(self, framedata, blit)
#    1234             self._blit_draw(self._drawn_artists, self._blit_cache)
#    1235         else:
# -> 1236             self._fig.canvas.draw_idle()
#    1237
#    1238     # The rest of the code in this class is to facilitate easy blitting
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in draw(self, renderer)
#     285                 sorted(self.collections,
#     286                        key=lambda col: col.do_3d_projection(renderer),
# --> 287                        reverse=True)):
#     288             col.zorder = zorder_offset + i
#     289         for i, patch in enumerate(
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in <lambda>(col)
#     284         for i, col in enumerate(
#     285                 sorted(self.collections,
# --> 286                        key=lambda col: col.do_3d_projection(renderer),
#     287                        reverse=True)):
#     288             col.zorder = zorder_offset + i
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\mpl_toolkits\mplot3d\art3d.py in do_3d_projection(self, renderer)
#     464         vxs, vys, vzs, vis = proj3d.proj_transform_clip(xs, ys, zs, renderer.M)
#     465
# --> 466         fcs = (zalpha(self._facecolor3d, vzs) if self._depthshade else
#     467                self._facecolor3d)
#     468         fcs = mcolors.to_rgba_array(fcs, self._alpha)
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\mpl_toolkits\mplot3d\art3d.py in zalpha(colors, zs)
#     778         norm = Normalize(min(zs), max(zs))
#     779         sats = 1 - norm(zs) * 0.7
# --> 780         colors = [(c[0], c[1], c[2], c[3] * s) for c, s in zip(colors, sats)]
#     781     return colors
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\mpl_toolkits\mplot3d\art3d.py in <listcomp>(.0)
#     778         norm = Normalize(min(zs), max(zs))
#     779         sats = 1 - norm(zs) * 0.7
# --> 780         colors = [(c[0], c[1], c[2], c[3] * s) for c, s in zip(colors, sats)]
#     781     return colors
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\numpy\ma\core.py in __getitem__(self, indx)
#    3161     view.__doc__ = ndarray.view.__doc__
#    3162
# -> 3163     def __getitem__(self, indx):
#    3164         """
#    3165         x.__getitem__(y) <==> x[y]
#
# KeyboardInterrupt:

# %%
dec.compile(optimizer=SGD(0.01, 0.9), loss='kld')
y_pred = dec.fit(x=unique_data, y=None, tol=0.01, maxiter=2e4, batch_size=2048,
                 update_interval=200, save_dir=folder_name)

# %%
plot_animated_history(dec.encoders_clustering_history[:],threeD=True,saving_name=folder_name+'/clustering.mp4')

# %%
pickle.dump(dec.encoders_clustering_history[:],
            open(folder_name+'/pretraining_hist.p',
                  "wb"),
                  protocol=4)

# %%
Encoded = dec.encoder.predict(x_train_r)
#Clusters_p = dec.model.predict(unique_data)

clrs = sns.color_palette("hls", dec.n_clusters)
fig, ax = plt.subplots(1,figsize=(15,15))
for i in range(len(Encoded)):
    #idx = Clusters_p[i].argmax()
    point = ax.scatter(Encoded[i,1], Encoded[i,0], s=2)
    point.set_color(clrs[y_train[i]])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-12869bb8ed79> in <module>
#       6 for i in range(len(Encoded)):
#       7     #idx = Clusters_p[i].argmax()
# ----> 8     point = ax.scatter(Encoded[i,1], Encoded[i,0], s=2)
#       9     point.set_color(clrs[y_train[i]])
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4325
#    4326         self.add_collection(collection)
# -> 4327         self.autoscale_view()
#    4328
#    4329         return collection
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in autoscale_view(self, tight, scalex, scaley)
#    2427             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2428             y_stickies = sum([sticky.y for sticky in stickies], [])
# -> 2429             if self.get_xscale().lower() == 'log':
#    2430                 x_stickies = [xs for xs in x_stickies if xs > 0]
#    2431             if self.get_yscale().lower() == 'log':
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000000001D84D510> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     881     def draw(self, renderer):
#     882         self.set_sizes(self._sizes, self.figure.dpi)
# --> 883         Collection.draw(self, renderer)
#     884
#     885
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     293         do_single_path_optimization = False
#     294         if (len(paths) == 1 and len(trans) <= 1 and
# --> 295             len(facecolors) == 1 and len(edgecolors) == 1 and
#     296             len(self._linewidths) == 1 and
#     297             self._linestyles == [(None, None)] and
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000000001D85AD90> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2052                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#    2055                     if pad is None:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2268
#    2269         for a in artists:
# -> 2270             bbox = a.get_tightbbox(renderer)
#    2271             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2272                 bb.append(bbox)
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4394
#    4395         for a in bbox_artists:
# -> 4396             bbox = a.get_tightbbox(renderer)
#    4397             if (bbox is not None and
#    4398                     (bbox.width != 0 or bbox.height != 0) and
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in get_tightbbox(self, renderer)
#     269         """
#     270
# --> 271         bbox = self.get_window_extent(renderer)
#     272         if self.get_clip_on():
#     273             clip_box = self.get_clip_box()
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\collections.py in get_window_extent(self, renderer)
#     212         # TODO:check to ensure that this does not fail for
#     213         # cases other than scatter plot legend
# --> 214         return self.get_datalim(transforms.IdentityTransform())
#     215
#     216     def _prepare_points(self):
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\collections.py in get_datalim(self, transData)
#     203             result = mpath.get_path_collection_extents(
#     204                 transform.frozen(), paths, self.get_transforms(),
# --> 205                 offsets, transOffset.frozen())
#     206             result = result.inverse_transformed(transData)
#     207         else:
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    2377     def frozen(self):
#    2378         self._invalid = 0
# -> 2379         frozen = composite_transform_factory(self._a.frozen(), self._b.frozen())
#    2380         if not isinstance(frozen, CompositeGenericTransform):
#    2381             return frozen.frozen()
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    2379         frozen = composite_transform_factory(self._a.frozen(), self._b.frozen())
#    2380         if not isinstance(frozen, CompositeGenericTransform):
# -> 2381             return frozen.frozen()
#    2382         return frozen
#    2383     frozen.__doc__ = Transform.frozen.__doc__
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    1797
#    1798     def frozen(self):
# -> 1799         return Affine2D(self.get_matrix().copy())
#    1800     frozen.__doc__ = AffineBase.frozen.__doc__
#    1801
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1878         If *matrix* is None, initialize with the identity transform.
#    1879         """
# -> 1880         Affine2DBase.__init__(self, **kwargs)
#    1881         if matrix is None:
#    1882             # A bit faster than np.identity(3).
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\transforms.py in __init__(self, *args, **kwargs)
#    1724
#    1725     def __init__(self, *args, **kwargs):
# -> 1726         Transform.__init__(self, *args, **kwargs)
#    1727         self._inverted = None
#    1728
#
# c:\users\ali\appdata\local\programs\python\python36\lib\site-packages\matplotlib\transforms.py in __init__(self, shorthand_name)
#      96         # TransformNodes start out as invalid until their values are
#      97         # computed for the first time.
# ---> 98         self._invalid = 1
#      99         self._shorthand_name = shorthand_name or ''
#     100
#
# KeyboardInterrupt:

# %%
loc = r'/home/alireza/Clustering/'
labeled_accounts = pd.read_csv(loc+ "/labeled_accounts.csv",sep=';',encoding='cp437')[:805]
unique_ones,b,counts = np.unique(labeled_accounts['TXT50'].values,return_inverse=True,return_counts=True)
idx = np.where(counts!=1)[0]
for acc in unique_ones[idx]:
    idx2 = np.where(labeled_accounts['TXT50'].values==acc)[0]
    labeled_accounts.loc[idx2[0],'TXT50'] = labeled_accounts.loc[idx2[0],'TXT50']+'_DUPLICATE'
len(np.unique(labeled_accounts['TXT50'].values))
Acc_frq_in_Dset = pd.DataFrame(np.sum(unique_data,axis=0), index=labeled_accounts['TXT50'].values.tolist(),
                                                           columns=['In_dataset_frequency'])
Acc_frq_in_Dset.index.name = 'Accounts_label'

# %%
Clusters_p = dec.model.predict(unique_data)
clusters_list=[]
for i in range(unique_data.shape[0]):
    cluster_id = Clusters_p[i].argmax()
    active_accounts = labeled_accounts.loc[np.where(unique_data[i]==1)[0]]['TXT50'].values
    
    clusters_list.append([cluster_id,
                          active_accounts,
                          len(active_accounts)])
       
clusters_df=pd.DataFrame(clusters_list,
                         columns=['Cluster_id', 'Active_acounts_label','N_active_accounts'])

# %%
all_clusters_info= []
for cluster_id in range(dec.n_clusters):
    
    Cluster = clusters_df.loc[clusters_df['Cluster_id']==cluster_id]
    Cluster_size = len(Cluster)
    cluster_acc = Cluster['Active_acounts_label'].values
    
    All_acc_in_clst = []
    for i in range(len(cluster_acc)):
        All_acc_in_clst += [acc for acc in cluster_acc[i]]
    In_cluster_unique_accs, In_clst_frq = np.unique(All_acc_in_clst, return_counts=True)
    In_Dset_frq = []
    for account in In_cluster_unique_accs:
        Dset_frq = Acc_frq_in_Dset.at[account,'In_dataset_frequency']
        #print(account,type(Dset_frq))
        In_Dset_frq.append(Dset_frq)
    
    accounts_info = np.asarray((In_cluster_unique_accs,
                                In_clst_frq,
                                In_Dset_frq,
                                np.round(In_clst_frq/Cluster_size,decimals=1),
                                np.round(In_clst_frq/In_Dset_frq, decimals=1),
                                #np.round(In_clst_frq/len(All_acc_in_clst),decimals=2)
                               )).T
    Cluster_info_df = pd.DataFrame(accounts_info,
                                   columns=['Unique_accounts',
                                            'In_cluster_frequency',
                                            'In_dataset_frequency',
                                            'In_cluster_frequency/cluster_size',
                                            'In_cluster_frequency/In_dataset_frequency',
                                            #'In_cluster_frequency/len(All_accounts_in_cluster)'
                                           ])
    all_clusters_info.append([Cluster_info_df, Cluster_size])
    
all_Clusters_info_df = pd.DataFrame(all_clusters_info, columns=['Cluster_info_DataFrame','Cluster_size'])
all_Clusters_info_df.index.name = 'Cluster_id'

# %%
all_Clusters_info_df

# %%
all_Clusters_info_df.at[8,'Cluster_info_DataFrame'].sort_values(by=['In_cluster_frequency/cluster_size','In_cluster_frequency/In_dataset_frequency'], ascending=False)

# %%
pickle.dump(all_Clusters_info_df,
            open(folder_name+'/Clusters_df.p',
                  "wb"),
                  protocol=4)

# %%
pickle.dump(dec,
            open(folder_name+'/dec_model.p',
                  "wb"),
                  protocol=4)
